# %% [markdown]
# CONDITITON STATEMENET
# - IF : Multiple Conditions
# - ELIF : Multiple Conditions
# - ESLE IF : Single Conditions
# - NESTED IF : Multiple Condition but with different concept

# %%
marks = 85 
if marks >= 90:
    print("A+")
if  marks >= 75:
    print("A")
if marks >= 60:
    print("B")
if marks <60:
    print("Fail")
# Out:
# A
# B

# %%
marks = 85 
if marks >= 90:
    print("A+")
elif  marks >= 75:
    print("A")
elif marks >= 60:
    print("B")
elif marks <60:
    print("Fail")
else:
    print("Invalid marks")
# Out:
# A

# %%
age = 90 
if age >= 18:
    print('You are eligible to vote')
else:
    print('you are not eligible to vote')
# Out:
# You are eligible to vote

# %%
username = str(input("Enter your username: "))
email = str(input("Enter your email: "))
password = str(input("Enter  your password: "))
c_password = str(input("Enter your password: "))

if len(username) >= 8 and len(username) <= 15:
    if "@" in email  and "." in email:
        if len(password)>= 8 and len(password)<= 15:
            if passweord==c_password:
                print("Registeration successful")
            else:
                print("Password does not match")
        else:
            print("Password must be between 8 and 15 characters")
    else:
        print("Invaild email  format")
else:
    print("U sername must be between 8 and 15 characters")

# %%
age = int(input("Enter  your age: "))
marks = int(input("Enter your marks: "))

if age>= 18:
    if marks>= 60:
        if age>=18 and  marks>=60:
            print("Admission milega")
        else:
            print("Nahi milega")
    else:
        print("Not eligable")
else:
    print("age is not 18 ")
# Out:
# age is not 18

# %% [markdown]
#  #  Take input from user for n variable and calculate the sum of those n numbers
#
#  # Print a table of 5 in proper table format
#
#  # Take a number from the user and count digits in a number
#
#  # Write a program to guess a secret number. Take a secret number then take an input from the user for the guessed number.

# %%
# Take input from user for n variable and calculate the sum of those n numbers
n = int(input("ENTER HOW MANY NUMBERS YOU WANTS TO ADD: "))

sum = 0

for i in range(n):
    num = int(input("ENTER A NUMBER : "))
    sum = sum + num
print("SUM:" , sum)
# Out:
# SUM: 13

# %%
# Print a table of 5 in proper table format
n= int(input("Enter a number: "))

if n==5:
    print("5 * 1 = 5")
    print("5 * 2 = 10")
    print("5 * 3 = 15")
    print("5 * 4 = 20")
    print("5 * 5 = 25")
    print("5 * 6 = 30")
    print("5 * 7 = 35")
    print("5 * 8 = 40")
    print("5 * 9 = 45")
    print("5 * 10 = 50")
else:
    print("Enter 5 only")
# Out:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %%
 # Take a number from the user and count digits in a number
n = str(int(input("Enter a number: ")))

print(len(n))
# Out:
# 5

# %%
 # Write a program to guess a secret number. Take a secret number then take an input from the user for the guessed number.
