# %%
a = 10
b = 3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a//b)
print(a**b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1
# 3
# 1000

# %%
a = 10
a+= 5
print(a)
# Out:
# 15

# %%
a -= 5 
print(a)
# Out:
# 10

# %%
a *= 10 
print(a)
# Out:
# 100

# %%
x= 10
y= 5 
z= 7
x>y and y<z
# Out:
# True

# %%
x>y or y>z
# Out:
# True

# %%
not(x>y and y<z)
# Out:
# False

# %%
x is y
# Out:
# False

# %%
x is not  y
# Out:
# True

# %%
email = "aleemkhan@200327gmail.com"
"@" in email
# Out:
# True

# %%
a=input("Enter a number")
print(a)
