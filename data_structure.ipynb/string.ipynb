# %%
name = str(input())
print(name[:3])
# Out:
# ale

# %%
x = "Beautiful"
y = "Hey"
print(x+y) #String concatenation
# Out:
# BeautifulHey

# %%
a = "hey"
print(a*5) #string dupication
# Out:
# heyheyheyheyhey

# %%
x = "Beautiful"
y = "Hey"
x.lower()
# Out:
# 'beautiful'

# %%
x.capitalize
# Out:
# <function str.capitalize()>

# %%
Poem = '''jonny jonny yes papa
eating sugar no papa
telling lie no papa
open your mouth no papa'''
print(Poem)
# Out:
# jonny jonny yes papa
# eating sugar no papa
# telling lie no papa
# open your mouth no papa

# %%
Poem.find("papa")
# Out:
# 16

# %%
a = Peom.replace("papa", "fufa").replace("sugar","poison").replace("eating","drinking")
print(a)
# Out:
# Jonney  Jonney yes fufa
# drinking poison no fufa
# telling lie no fufa
# open your mouth hahaha

# %%
a.split()
# Out:
# ['Jonney',
#  'Jonney',
#  'yes',
#  'fufa',
#  'drinking',
#  'poison',
#  'no',
#  'fufa',
#  'telling',
#  'lie',
#  'no',
#  'fufa',
#  'open',
#  'your',
#  'mouth',
#  'hahaha']

# %%
"hello".isalpha()
# Out:
# True

# %%
"123".isdigit()
# Out:
# True

# %%
"hello123".isalnum()
# Out:
# True

# %%
"Hello World".swapcase()
# Out:
# 'hELLO wORLD'

# %%
len(a)
# Out:
# 92
