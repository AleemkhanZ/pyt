# %%
name = str(input())
print(name[:3])
# Out:
# ale

# %%
x = "Beautiful"
y = "Hey"
print(x+y) #String concatenation
# Out:
# BeautifulHey

# %%
a = "hey"
print(a*5) #string dupication
# Out:
# heyheyheyheyhey

# %%
x = "Beautiful"
y = "Hey"
x.lower()
# Out:
# 'beautiful'

# %%
x.upper()
# Out:
# 'BEAUTIFUL'

# %%
x.capitalize()
# Out:
# 'Beautiful'

# %%
a = "all is well"
a.title()
# Out:
# 'All Is Well'

# %%
Poem = '''jonny jonny yes papa
eating sugar no papa
telling lie no papa
open your mouth no papa'''
print(Poem)
# Out:
# jonny jonny yes papa
# eating sugar no papa
# telling lie no papa
# open your mouth no papa

# %%
Poem.find("papa")
# Out:
# 16

# %%
p = Poem.replace("papa", "fufa").replace("sugar","poison").replace("eating","drinking")
print(p)
# Out:
# jonny jonny yes fufa
# drinking poison no fufa
# telling lie no fufa
# open your mouth no fufa

# %%
a.split()
# Out:
# ['all', 'is', 'well']

# %%
p.splitlines()
# Out:
# ['jonny jonny yes fufa',
#  'drinking poison no fufa',
#  'telling lie no fufa',
#  'open your mouth no fufa']

# %%
text = " hello "
text.strip()
# Out:
# 'hello'

# %%
a.count('l')
# Out:
# 4

# %%
a.startswith('a')
# Out:
# True

# %%
a.endswith("l")
# Out:
# True

# %%
"hello".isalpha()
# Out:
# True

# %%
"123".isdigit()
# Out:
# True

# %%
"hello123".isalnum()
# Out:
# True

# %%
"Hello World".swapcase()
# Out:
# 'hELLO wORLD'

# %%
len(a)
# Out:
# 11

# %%
"hello".index('l')
# Out:
# 2
